# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.utils import shuffle
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import log_loss
import matplotlib.pyplot as plt
import math
import random
import csv

# %matplotlib inline

# %% [markdown]
# # NCAA Bracket

# %%
# folder = 'DataFiles2018/Stage2UpdatedDataFiles'
folder = 'Stage2DataFiles'
prediction_year = 2019

# %%
# df_seeds = pd.read_csv(folder + '/NCAATourneySeeds.csv')
# df_slots = pd.read_csv(folder + '/NCAATourneySlots.csv')
# df_tour = pd.read_csv(folder + '/NCAATourneyCompactResults.csv')
# df_teams = pd.read_csv(folder + '/Teams.csv')
# df_massey = pd.read_csv(folder + '/MasseyOrdinals_thruSeason2018_Day128.csv')
# df_tour_detailed = pd.read_csv(folder + '/NCAATourneyDetailedResults.csv')
# df_seasons = pd.read_csv(folder + '/Stage2UpdatedDataFiles/Seasons.csv')
# df_538 = pd.read_csv(folder + '/fivethirtyeight_ncaa_forecasts.csv')
# df_reg = pd.read_csv(folder + '/RegularSeasonCompactResults.csv')
# df_reg_det = pd.read_csv(folder + '/RegularSeasonDetailedResults.csv')
# df_sample_stage2 = pd.read_csv(folder + '/SampleSubmissionStage2.csv')

# %% [markdown]
# ## Make ELO rating from scratch

# %%
def calc_elo(win_team, lose_team, season):
    winner_rank = get_elo(season, win_team)
    loser_rank = get_elo(season, lose_team)

    """
    This is originally from from:
    http://zurb.com/forrst/posts/An_Elo_Rating_function_in_Python_written_for_foo-hQl
    """
    rank_diff = winner_rank - loser_rank
    exp = (rank_diff * -1) / 400
    odds = 1 / (1 + math.pow(10, exp))
    if winner_rank < 2100:
        k = 32
    elif winner_rank >= 2100 and winner_rank < 2400:
        k = 24
    else:
        k = 16
    new_winner_rank = round(winner_rank + (k * (1 - odds)))
    new_rank_diff = new_winner_rank - winner_rank
    new_loser_rank = loser_rank - new_rank_diff

    return new_winner_rank, new_loser_rank

# %%
base_elo = 1600
team_elos = {}  # Reset each year.
team_stats = {}

def initialize_data():
    for i in range(2003, prediction_year+1):
        team_elos[i] = {}
        team_stats[i] = {}

# %%
def get_elo(season, team):
    try:
        return team_elos[season][team]
    except:
        try:
            # Get the previous season's ending value.
            team_elos[season][team] = team_elos[season-1][team]
            return team_elos[season][team]
        except:
            # Get the starter elo.
            team_elos[season][team] = base_elo
            return team_elos[season][team]

# %%
def predict_winner(team_1, team_2, model, season, stat_fields):
    features = []

    # Team 1
    features.append(get_elo(season, team_1))
    for stat in stat_fields:
        features.append(get_stat(season, team_1, stat))

    # Team 2
    features.append(get_elo(season, team_2))
    for stat in stat_fields:
        features.append(get_stat(season, team_2, stat))

    return model.predict_proba([features])

# %%
def update_stats(season, team, fields):
    """
    This accepts some stats for a team and udpates the averages.
    First, we check if the team is in the dict yet. If it's not, we add it.
    Then, we try to check if the key has more than 5 values in it.
        If it does, we remove the first one
        Either way, we append the new one.
    If we can't check, then it doesn't exist, so we just add this.
    Later, we'll get the average of these items.
    """
    if team not in team_stats[season]:
        team_stats[season][team] = {}

    for key, value in fields.items():
        # Make sure we have the field.
        if key not in team_stats[season][team]:
            team_stats[season][team][key] = []

        if len(team_stats[season][team][key]) >= 15:
            team_stats[season][team][key].pop(0)
        team_stats[season][team][key].append(value)

# %%
def get_stat(season, team, field):
    try:
        l = team_stats[season][team][field]
        return sum(l) / float(len(l))
    except:
        return 0

# %%
def build_team_dict():
    team_ids = pd.read_csv(folder + '/Teams.csv')
    team_id_map = {}
    for index, row in team_ids.iterrows():
        team_id_map[row['TeamID']] = row['TeamName']
    return team_id_map

# %%
# Set up data for the X and y
# New way 2019

X = []
y = []

def build_season_data(all_data):
    # Calculate the elo for every game for every team, each season.
    # Store the elo per season so we can retrieve their end elo
    # later in order to predict the tournaments without having to
    # inject the prediction into this loop.
    print("Building season data.")
    for index, row in all_data.iterrows():
        # Used to skip matchups where we don't have usable stats yet.
        skip = 0

        # Get starter or previous elos.
        team_1_elo = get_elo(row['Season'], row['WTeamID'])
        team_2_elo = get_elo(row['Season'], row['LTeamID'])

        # Add 100 to the home team (# taken from Nate Silver analysis.)
        if row['WLoc'] == 'H':
            team_1_elo += 100
        elif row['WLoc'] == 'A':
            team_2_elo += 100

        # We'll create some arrays to use later.
        team_1_features = [team_1_elo]
        team_2_features = [team_2_elo]

        # Build arrays out of the stats we're tracking..
        for field in stat_fields:
            team_1_stat = get_stat(row['Season'], row['WTeamID'], field)
            team_2_stat = get_stat(row['Season'], row['LTeamID'], field)
            if team_1_stat is not 0 and team_2_stat is not 0:
                team_1_features.append(team_1_stat)
                team_2_features.append(team_2_stat)
            else:
                skip = 1

        if skip == 0:  # Make sure we have stats.
            # Randomly select left and right and 0 or 1 so we can train
            # for multiple classes.
            if random.random() > 0.5:
                X.append(team_1_features + team_2_features)
                y.append(0)
            else:
                X.append(team_2_features + team_1_features)
                y.append(1)

        # AFTER we add the current stuff to the prediction, update for
        # next time. Order here is key so we don't fit on data from the
        # same game we're trying to predict.
        if row['WFTA'] != 0 and row['LFTA'] != 0:
            stat_1_fields = {
                'Score': row['WScore'],
                'FGP': row['WFGM'] / row['WFGA'] * 100,
                'FGA': row['WFGA'],
                'FGA3': row['WFGA3'],
                '3PP': row['WFGM3'] / row['WFGA3'] * 100,
                'FTP': row['WFTM'] / row['WFTA'] * 100,
                'OR': row['WOR'],
                'DR': row['WDR'],
                'AST': row['WAst'],
                'TO': row['WTO'],
                'STL': row['WStl'],
                'BLK': row['WBlk'],
                'PF': row['WPF'],
                'POSS': row['WFGA'] + 0.475 * row['WFTA'] - row['WOR'] + row['WTO'],
                'PPP': row['WScore']/(row['WFGA'] + 0.475 * row['WFTA'] - row['WOR'] + row['WTO']),
                'EM': (row['WScore']/(row['WFGA'] + 0.475 * row['WFTA'] - row['WOR'] + row['WTO']) - 
                       row['LScore']/(row['LFGA'] + 0.475 * row['LFTA'] - row['LOR'] + row['LTO'])),
                'OffRtg': row['WOffRtg'],
                'DefRtg': row['WDefRtg'],
                'NetRtg': row['WNetRtg'],
                'AstR': row['WAstR'],
                'TOR': row['WTOR'],
                'TSP': row['WTSP'],
                'eFGP': row['WeFGP'],
                'FTAR': row['WFTAR'],
                'ORP': row['WORP'],
                'DRP': row['WDRP'],
                'RP': row['WRP']
       }
            stat_2_fields = {
                'Score': row['LScore'],
                'FGP': row['LFGM'] / row['LFGA'] * 100,
                'FGA': row['LFGA'],
                'FGA3': row['LFGA3'],
                '3PP': row['LFGM3'] / row['LFGA3'] * 100,
                'FTP': row['LFTM'] / row['LFTA'] * 100,
                'OR': row['LOR'],
                'DR': row['LDR'],
                'AST': row['LAst'],
                'TO': row['LTO'],
                'STL': row['LStl'],
                'BLK': row['LBlk'],
                'PF': row['LPF'],
                'POSS': row['LFGA'] + 0.475 * row['LFTA'] - row['LOR'] + row['LTO'],
                'PPP': row['LScore']/(row['LFGA'] + 0.475 * row['LFTA'] - row['LOR'] + row['LTO']),
                'EM': (row['LScore']/(row['LFGA'] + 0.475 * row['LFTA'] - row['LOR'] + row['LTO']) - 
                       row['WScore']/(row['WFGA'] + 0.475 * row['WFTA'] - row['WOR'] + row['WTO'])),
                'OffRtg': row['LOffRtg'],
                'DefRtg': row['LDefRtg'],
                'NetRtg': row['LNetRtg'],
                'AstR': row['LAstR'],
                'TOR': row['LTOR'],
                'TSP': row['LTSP'],
                'eFGP': row['LeFGP'],
                'FTAR': row['LFTAR'],
                'ORP': row['LORP'],
                'DRP': row['LDRP'],
                'RP': row['LRP']
            }
            update_stats(row['Season'], row['WTeamID'], stat_1_fields)
            update_stats(row['Season'], row['LTeamID'], stat_2_fields)

        # Now that we've added them, calc the new elo.
        new_winner_rank, new_loser_rank = calc_elo(
            row['WTeamID'], row['LTeamID'], row['Season'])
        team_elos[row['Season']][row['WTeamID']] = new_winner_rank
        team_elos[row['Season']][row['LTeamID']] = new_loser_rank

    return X, y

# %%
pd.DataFrame(team_elos)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
X
# Out:
# []

# %% [markdown]
# ## Start of Final Function

# %%
stat_fields = ['Score','FGP', 'FGA', 'FGA3', '3PP', 'FTP', 'OR', 'DR', 'AST',
               'TO', 'STL', 'BLK', 'PF', 'POSS','PPP', 'EM', 'OffRtg','DefRtg',
               'NetRtg','AstR','TOR','TSP','eFGP','FTAR', 'ORP','DRP', 'RP']
initialize_data()
df_teams = pd.read_csv(folder + '/Teams.csv')
season_data = pd.read_csv(folder + '/RegularSeasonDetailedResults.csv')
tourney_data = pd.read_csv(folder + '/NCAATourneyDetailedResults.csv')
frames = [season_data, tourney_data]
all_data = pd.concat(frames)

# %%
all_data.shape
# Out:
# (88552, 34)

# %%
all_data.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#   ...   LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0 ...      10    16    22   10   22     8   18     9     2   20
# 1 ...      24     9    20   20   25     7   12     8     6   16
# 2 ...      26    14    23   31   22     9   12     2     5   23
# 3 ...      22     8    15   17   20     9   19     4     3   23
# 4 ...      16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]

# %%
df_teams_win = df_teams[['TeamID', 'TeamName']].rename(columns={'TeamID':'WTeamID', 'TeamName':'WTeam'})
df_teams_loss = df_teams[['TeamID', 'TeamName']].rename(columns={'TeamID':'LTeamID', 'TeamName':'LTeam'})

df_merge = pd.merge(left=all_data, right=df_teams_win, how='left', on='WTeamID')
all_data = pd.merge(left=df_merge, right=df_teams_loss, how='left', on='LTeamID')

# %%
all_data.shape
# Out:
# (88552, 36)

# %%
### New Advanced metrics to add


#Points Winning/Losing Team
all_data['WPts'] = all_data.apply(lambda row: 2*row.WFGM + row.WFGM3 + row.WFTM, axis=1)
all_data['LPts'] = all_data.apply(lambda row: 2*row.LFGM + row.LFGM3 + row.LFTM, axis=1)

#Calculate Winning/losing Team Possesion Feature
wPos = all_data.apply(lambda row: 0.96*(row.WFGA + row.WTO + 0.44*row.WFTA - row.WOR), axis=1)
lPos = all_data.apply(lambda row: 0.96*(row.LFGA + row.LTO + 0.44*row.LFTA - row.LOR), axis=1)
#two teams use almost the same number of possessions in a game
#(plus/minus one or two - depending on how quarters end)
#so let's just take the average
all_data['Pos'] = (wPos+lPos)/2

# %%
#Offensive efficiency (OffRtg) = 100 x (Points / Possessions)
all_data['WOffRtg'] = all_data.apply(lambda row: 100 * (row.WPts / row.Pos), axis=1)
all_data['LOffRtg'] = all_data.apply(lambda row: 100 * (row.LPts / row.Pos), axis=1)
#Defensive efficiency (DefRtg) = 100 x (Opponent points / Opponent possessions)
all_data['WDefRtg'] = all_data.LOffRtg
all_data['LDefRtg'] = all_data.WOffRtg
#Net Rating = Off.Rtg - Def.Rtg
all_data['WNetRtg'] = all_data.apply(lambda row:(row.WOffRtg - row.WDefRtg), axis=1)
all_data['LNetRtg'] = all_data.apply(lambda row:(row.LOffRtg - row.LDefRtg), axis=1)
                         
#Assist Ratio : Percentage of team possessions that end in assists
all_data['WAstR'] = all_data.apply(lambda row: 100 * row.WAst / (row.WFGA + 0.44*row.WFTA + row.WAst + row.WTO), axis=1)
all_data['LAstR'] = all_data.apply(lambda row: 100 * row.LAst / (row.LFGA + 0.44*row.LFTA + row.LAst + row.LTO), axis=1)
#Turnover Ratio: Number of turnovers of a team per 100 possessions used.
#(TO * 100) / (FGA + (FTA * 0.44) + AST + TO)
all_data['WTOR'] = all_data.apply(lambda row: 100 * row.WTO / (row.WFGA + 0.44*row.WFTA + row.WAst + row.WTO), axis=1)
all_data['LTOR'] = all_data.apply(lambda row: 100 * row.LTO / (row.LFGA + 0.44*row.LFTA + row.LAst + row.LTO), axis=1)
                    
#The Shooting Percentage : Measure of Shooting Efficiency (FGA/FGA3, FTA)
all_data['WTSP'] = all_data.apply(lambda row: 100 * row.WPts / (2 * (row.WFGA + 0.44 * row.WFTA)), axis=1)
all_data['LTSP'] = all_data.apply(lambda row: 100 * row.LPts / (2 * (row.LFGA + 0.44 * row.LFTA)), axis=1)
#eFG% : Effective Field Goal Percentage adjusting for the fact that 3pt shots are more valuable 
all_data['WeFGP'] = all_data.apply(lambda row:(row.WFGM + 0.5 * row.WFGM3) / row.WFGA, axis=1)      
all_data['LeFGP'] = all_data.apply(lambda row:(row.LFGM + 0.5 * row.LFGM3) / row.LFGA, axis=1)   
#FTA Rate : How good a team is at drawing fouls.
all_data['WFTAR'] = all_data.apply(lambda row: row.WFTA / row.WFGA, axis=1)
all_data['LFTAR'] = all_data.apply(lambda row: row.LFTA / row.LFGA, axis=1)
                         
#OREB% : Percentage of team offensive rebounds
all_data['WORP'] = all_data.apply(lambda row: row.WOR / (row.WOR + row.LDR), axis=1)
all_data['LORP'] = all_data.apply(lambda row: row.LOR / (row.LOR + row.WDR), axis=1)
#DREB% : Percentage of team defensive rebounds
all_data['WDRP'] = all_data.apply(lambda row: row.WDR / (row.WDR + row.LOR), axis=1)
all_data['LDRP'] = all_data.apply(lambda row: row.LDR / (row.LDR + row.WOR), axis=1)                                      
#REB% : Percentage of team total rebounds
all_data['WRP'] = all_data.apply(lambda row: (row.WDR + row.WOR) / (row.WDR + row.WOR + row.LDR + row.LOR), axis=1)
all_data['LRP'] = all_data.apply(lambda row: (row.LDR + row.LOR) / (row.WDR + row.WOR + row.LDR + row.LOR), axis=1)

# %%
all_data.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#      ...        WeFGP     LeFGP     WFTAR     LFTAR      WORP      LORP  \
# 0    ...     0.491379  0.433962  0.310345  0.415094  0.388889  0.294118
# 1    ...     0.483871  0.402985  0.306452  0.298507  0.375000  0.416667
# 2    ...     0.482759  0.321918  0.500000  0.315068  0.435897  0.543860
# 3    ...     0.513158  0.428571  0.815789  0.306122  0.230769  0.472222
# 4    ...     0.540984  0.435484  0.213115  0.435484  0.531250  0.488372
#
#        WDRP      LDRP       WRP       LRP
# 0  0.705882  0.611111  0.542857  0.457143
# 1  0.583333  0.625000  0.488636  0.511364
# 2  0.456140  0.564103  0.447917  0.552083
# 3  0.527778  0.769231  0.403226  0.596774
# 4  0.511628  0.468750  0.520000  0.480000
#
# [5 rows x 61 columns]

# %%
X, y = build_season_data(all_data)
# Out:
# Building season data.

# %%
# Create Dataframe to make it easier to see what we have
df_X = pd.DataFrame(X, columns=['ELO', 'Score','FGP', 'FGA', 'FGA3', '3PP', 'FTP', 'OR', 'DR', 'AST',
               'TO', 'STL', 'BLK', 'PF', 'POSS','PPP', 'EM', 'OffRtg','DefRtg',
               'NetRtg','AstR','TOR','TSP','eFGP','FTAR', 'ORP','DRP', 'RP',
                'LELO', 'LScore','LFGP', 'LFGA', 'LFGA3', 'L3PP', 'LFTP', 'LOR', 'LDR', 'LAST',
               'LTO', 'LSTL', 'LBLK', 'LPF', 'LPOSS', 'LPPP', 'LEM', 'LOffRtg','LDefRtg',
               'LNetRtg','LAstR','LTOR','LTSP','LeFGP','LFTAR', 'LORP','LDRP', 'LRP'])

# %%
#    Original Code
#     # Fit the model.
#     print("Fitting on %d samples." % len(X))

#     model = linear_model.LogisticRegression()

#     # Check accuracy.
#     print("Doing cross-validation.")
#     print(cross_validation.cross_val_score(
#         model, numpy.array(X), numpy.array(y), cv=10, scoring='accuracy', n_jobs=-1
#     ).mean())

#     model.fit(X, y)

# %%
# # Fit the model.
# print("Fitting on %d samples." % len(X))


# # X_features = ['ELO','AST','PPP','3PP','EM','LELO','LAST','LPPP','L3PP','LEM']
# # Xdf = df_X.values

# # ss = StandardScaler()
# # Xs = ss.fit_transform(X)

# # logreg = LogisticRegression()
# # params = {'C': np.logspace(start=-5, stop=3, num=9)}

gb = GradientBoostingClassifier(n_estimators=250)
params = {'max_depth': [2]}
model = GridSearchCV(gb, params, scoring='neg_log_loss', refit=True)
model.fit(X, y)
print('Best log_loss: {:.4}, with best params: {}'.format(model.best_score_, model.best_params_))

# # # Check accuracy.
# # print("Doing cross-validation.")
# # print(cross_val_score(
# #     model, np.array(Xs), np.array(y), cv=10, scoring='neg_log_loss', n_jobs=-1
# # ).mean())

# # model.fit(X, y)
# Out:
# Best log_loss: -0.5315, with best params: {'max_depth': 2}

# %% [markdown]
# I first used a basic gradient boost model to see which features were the most important. Then I used a gridsearch for the actual model

# %%
# # Show feature importance
# model = GradientBoostingClassifier(n_estimators=250,max_depth=2)
# model.fit(X, y)

# def showFeatureImportance(my_categories):
#     fx_imp = pd.Series(model.feature_importances_, index=my_categories)
#     fx_imp /= fx_imp.max()
#     fx_imp = fx_imp.sort_values()
#     plt.figure(figsize=(20,10))
#     fx_imp.plot(kind='barh')
#     plt.savefig('Feature_Importances.png')
    
    
# showFeatureImportance(df_X.columns)

# %%
# Now predict tournament matchups.
print("Getting teams.")
df_teams_seeds = df_teams[['TeamID', 'TeamName']].rename(columns={'TeamName':'Team'})
seeds = pd.read_csv(folder + '/NCAATourneySeeds.csv')
seeds = pd.merge(left=seeds, right=df_teams_seeds, how='left', on='TeamID')
# for i in range(2017, 2018):
tourney_teams = []
for index, row in seeds.iterrows():
    if row['Season'] == prediction_year:
        tourney_teams.append(row['TeamID'])
# Out:
# Getting teams.

# %%
# Build our prediction of every matchup.
submission_data = []
print("Predicting matchups.")
tourney_teams.sort()
for team_a in tourney_teams:
    for team_b in tourney_teams:
        if team_a < team_b:
            prediction = predict_winner(
                team_a, team_b, model, prediction_year, stat_fields)
            label = str(prediction_year) + '_' + str(team_a) + '_' + \
                str(team_b)
            submission_data.append([label, prediction[0][0]])
# Out:
# Predicting matchups.

# %%
submission_data[:5]
# Out:
# [['2019_1101_1113', 0.24804091346657797],
#  ['2019_1101_1120', 0.16109031162832232],
#  ['2019_1101_1124', 0.2376811089230182],
#  ['2019_1101_1125', 0.21698278660474346],
#  ['2019_1101_1133', 0.4811107049696538]]

# %%
# Write the results.
print("Writing %d results." % len(submission_data))
with open(folder + '/submission.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['ID', 'Pred'])
    writer.writerows(submission_data)
# Out:
# Writing 2278 results.

# %%
# Now so that we can use this to fill out a bracket, create a readable
# version.
print("Outputting readable results.")
team_id_map = build_team_dict()
readable = []
less_readable = []  # A version that's easy to look up.
for pred in submission_data:
    parts = pred[0].split('_')
    less_readable.append(
        [team_id_map[int(parts[1])], team_id_map[int(parts[2])], pred[1]])
    # Order them properly.
    if pred[1] > 0.5:
        winning = int(parts[1])
        losing = int(parts[2])
        proba = pred[1]
    else:
        winning = int(parts[2])
        losing = int(parts[1])
        proba = 1 - pred[1]
    readable.append(
        [
            '%s beats %s: %f' %
            (team_id_map[winning], team_id_map[losing], proba)
        ]
    )
with open(folder + '/readable-predictions.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerows(readable)
with open(folder + '/less-readable-predictions.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerows(less_readable)
# Out:
# Outputting readable results.

# %%
# pd.read_csv('DataFiles2019/Stage2UpdatedDataFiles/submission.csv').head()
pd.read_csv(folder + '/submission.csv').head()
# Out:
#                ID      Pred
# 0             NaN       NaN
# 1  2019_1101_1113  0.248041
# 2             NaN       NaN
# 3  2019_1101_1120  0.161090
# 4             NaN       NaN

# %%
# df_predictions = pd.read_csv('DataFiles2019/Stage2UpdatedDataFiles/less-readable-predictions.csv',header=None)
df_predictions = pd.read_csv(folder + '/less-readable-predictions.csv',header=None)

# %%
pd.set_option('display.max_rows', 3000)

# %%
df_predictions
# Out:
#                     0                1         2
# 0         Abilene Chr       Arizona St  0.248041
# 1         Abilene Chr           Auburn  0.161090
# 2         Abilene Chr           Baylor  0.237681
# 3         Abilene Chr          Belmont  0.216983
# 4         Abilene Chr          Bradley  0.481111
# 5         Abilene Chr          Buffalo  0.175328
# 6         Abilene Chr       Cincinnati  0.171373
# 7         Abilene Chr          Colgate  0.398199
# 8         Abilene Chr             Duke  0.086396
# 9         Abilene Chr      F Dickinson  0.582837
# 10        Abilene Chr          Florida  0.252759
# 11        Abilene Chr       Florida St  0.134462
# 12        Abilene Chr     Gardner Webb  0.619385
# 13        Abilene Chr       Georgia St  0.381949
# 14        Abilene Chr          Gonzaga  0.074906
# 15        Abilene Chr          Houston  0.119827
# 16        Abilene Chr             Iona  0.519893
# 17        Abilene Chr             Iowa  0.307376
# 18        Abilene Chr          Iowa St  0.192150
# 19        Abilene Chr           Kansas  0.207649
# 20        Abilene Chr        Kansas St  0.133699
# 21        Abilene Chr         Kentucky  0.131513
# 22        Abilene Chr          Liberty  0.434737
# 23        Abilene Chr       Louisville  0.271414
# 24        Abilene Chr              LSU  0.157170
# 25        Abilene Chr        Marquette  0.204941
# 26        Abilene Chr         Maryland  0.275625
# 27        Abilene Chr         Michigan  0.132184
# 28        Abilene Chr      Michigan St  0.121951
# 29        Abilene Chr        Minnesota  0.337187
# 30        Abilene Chr      Mississippi  0.331912
# 31        Abilene Chr   Mississippi St  0.177089
# 32        Abilene Chr          Montana  0.327852
# 33        Abilene Chr        Murray St  0.252365
# 34        Abilene Chr      N Dakota St  0.645100
# 35        Abilene Chr       N Kentucky  0.352410
# 36        Abilene Chr       NC Central  0.708492
# 37        Abilene Chr           Nevada  0.131450
# 38        Abilene Chr    New Mexico St  0.176477
# 39        Abilene Chr   North Carolina  0.086930
# 40        Abilene Chr     Northeastern  0.273129
# 41        Abilene Chr          Ohio St  0.303207
# 42        Abilene Chr         Oklahoma  0.312466
# 43        Abilene Chr     Old Dominion  0.375027
# 44        Abilene Chr           Oregon  0.172979
# 45        Abilene Chr     Prairie View  0.598570
# 46        Abilene Chr           Purdue  0.127584
# 47        Abilene Chr       Seton Hall  0.226026
# 48        Abilene Chr        St John's  0.341535
# 49        Abilene Chr         St Louis  0.327934
# 50        Abilene Chr     St Mary's CA  0.242039
# 51        Abilene Chr         Syracuse  0.264275
# 52        Abilene Chr           Temple  0.255224
# 53        Abilene Chr        Tennessee  0.128714
# 54        Abilene Chr       Texas Tech  0.111091
# 55        Abilene Chr        UC Irvine  0.248414
# 56        Abilene Chr              UCF  0.278437
# 57        Abilene Chr          Utah St  0.205462
# 58        Abilene Chr  VA Commonwealth  0.166022
# 59        Abilene Chr          Vermont  0.240896
# 60        Abilene Chr        Villanova  0.136841
# 136            Auburn          Buffalo  0.632607
# 137            Auburn       Cincinnati  0.456938
# 138            Auburn          Colgate  0.838730
# 139            Auburn             Duke  0.302203
# 140            Auburn      F Dickinson  0.891498
# 141            Auburn          Florida  0.687570
# 142            Auburn       Florida St  0.421710
# 143            Auburn     Gardner Webb  0.900379
# 144            Auburn       Georgia St  0.848486
# 145            Auburn          Gonzaga  0.302267
# 146            Auburn          Houston  0.400788
# 147            Auburn             Iona  0.894425
# 148            Auburn             Iowa  0.751593
# 149            Auburn          Iowa St  0.568149
# 150            Auburn           Kansas  0.523977
# 151            Auburn        Kansas St  0.460343
# 152            Auburn         Kentucky  0.403593
# 153            Auburn          Liberty  0.861121
# 154            Auburn       Louisville  0.678052
# 155            Auburn              LSU  0.505988
# 156            Auburn        Marquette  0.592094
# 157            Auburn         Maryland  0.682660
# 158            Auburn         Michigan  0.416908
# 159            Auburn      Michigan St  0.387285
# 160            Auburn        Minnesota  0.769983
# 161            Auburn      Mississippi  0.777374
# 162            Auburn   Mississippi St  0.589863
# 163            Auburn          Montana  0.823216
# 164            Auburn        Murray St  0.741274
# 165            Auburn      N Dakota St  0.910541
# 166            Auburn       N Kentucky  0.844730
# 167            Auburn       NC Central  0.920716
# 168            Auburn           Nevada  0.507846
# 169            Auburn    New Mexico St  0.636091
# 170            Auburn   North Carolina  0.308120
# 171            Auburn     Northeastern  0.754245
# 172            Auburn          Ohio St  0.727144
# 173            Auburn         Oklahoma  0.728445
# 174            Auburn     Old Dominion  0.808361
# 175            Auburn           Oregon  0.596755
# 176            Auburn     Prairie View  0.891267
# 177            Auburn           Purdue  0.435983
# 178            Auburn       Seton Hall  0.613915
# 179            Auburn        St John's  0.765532
# 180            Auburn         St Louis  0.778262
# 181            Auburn     St Mary's CA  0.730318
# 182            Auburn         Syracuse  0.699104
# 183            Auburn           Temple  0.717339
# 184            Auburn        Tennessee  0.432207
# 185            Auburn       Texas Tech  0.374163
# 186            Auburn        UC Irvine  0.727236
# 187            Auburn              UCF  0.721184
# 188            Auburn          Utah St  0.676175
# 189            Auburn  VA Commonwealth  0.626756
# 190            Auburn          Vermont  0.736896
# 191            Auburn        Villanova  0.412531
# 192            Auburn         Virginia  0.270917
# 193            Auburn    Virginia Tech  0.521829
# 194            Auburn       Washington  0.667297
# 195            Auburn        Wisconsin  0.592098
# 196            Auburn          Wofford  0.699635
# 197            Auburn             Yale  0.844604
# 198            Baylor          Belmont  0.597764
# 199            Baylor          Bradley  0.812733
# 200            Baylor          Buffalo  0.499537
# 201            Baylor       Cincinnati  0.319905
# 202            Baylor          Colgate  0.776733
# 203            Baylor             Duke  0.203466
# 204            Baylor      F Dickinson  0.868076
# 205            Baylor          Florida  0.532239
# 206            Baylor       Florida St  0.309980
# 207            Baylor     Gardner Webb  0.866359
# 208            Baylor       Georgia St  0.765054
# 209            Baylor          Gonzaga  0.196901
# 210            Baylor          Houston  0.304658
# 211            Baylor             Iona  0.831504
# 212            Baylor             Iowa  0.637248
# 213            Baylor          Iowa St  0.399784
# 214            Baylor           Kansas  0.379978
# 448        Cincinnati          Colgate  0.825603
# 449        Cincinnati             Duke  0.338580
# 450        Cincinnati      F Dickinson  0.886702
# 451        Cincinnati          Florida  0.664111
# 452        Cincinnati       Florida St  0.445893
# 453        Cincinnati     Gardner Webb  0.890209
# 454        Cincinnati       Georgia St  0.834440
# 455        Cincinnati          Gonzaga  0.316652
# 456        Cincinnati          Houston  0.446317
# 457        Cincinnati             Iona  0.882638
# 458        Cincinnati             Iowa  0.754792
# 459        Cincinnati          Iowa St  0.594169
# 460        Cincinnati           Kansas  0.537317
# 461        Cincinnati        Kansas St  0.495056
# 462        Cincinnati         Kentucky  0.440524
# 463        Cincinnati          Liberty  0.859663
# 464        Cincinnati       Louisville  0.685706
# 465        Cincinnati              LSU  0.546099
# 466        Cincinnati        Marquette  0.616962
# 467        Cincinnati         Maryland  0.710151
# 468        Cincinnati         Michigan  0.458038
# 469        Cincinnati      Michigan St  0.423524
# 470        Cincinnati        Minnesota  0.765843
# 471        Cincinnati      Mississippi  0.762143
# 472        Cincinnati   Mississippi St  0.597549
# 473        Cincinnati          Montana  0.809398
# 474        Cincinnati        Murray St  0.728583
# 475        Cincinnati      N Dakota St  0.901062
# 476        Cincinnati       N Kentucky  0.831057
# 477        Cincinnati       NC Central  0.913312
# 478        Cincinnati           Nevada  0.550289
# 479        Cincinnati    New Mexico St  0.626116
# 480        Cincinnati   North Carolina  0.346249
# 481        Cincinnati     Northeastern  0.738112
# 482        Cincinnati          Ohio St  0.726159
# 483        Cincinnati         Oklahoma  0.723972
# 484        Cincinnati     Old Dominion  0.781477
# 485        Cincinnati           Oregon  0.613497
# 486        Cincinnati     Prairie View  0.884599
# 487        Cincinnati           Purdue  0.481764
# 488        Cincinnati       Seton Hall  0.654728
# 489        Cincinnati        St John's  0.765775
# 490        Cincinnati         St Louis  0.749033
# 491        Cincinnati     St Mary's CA  0.719578
# 492        Cincinnati         Syracuse  0.692867
# 493        Cincinnati           Temple  0.710212
# 494        Cincinnati        Tennessee  0.455844
# 495        Cincinnati       Texas Tech  0.410189
# 496        Cincinnati        UC Irvine  0.712360
# 497        Cincinnati              UCF  0.694764
# 498        Cincinnati          Utah St  0.667413
# 499        Cincinnati  VA Commonwealth  0.627666
# 500        Cincinnati          Vermont  0.717915
# 501        Cincinnati        Villanova  0.444415
# 502        Cincinnati         Virginia  0.298899
# 503        Cincinnati    Virginia Tech  0.554838
# 504        Cincinnati       Washington  0.639156
# 505        Cincinnati        Wisconsin  0.600593
# 506        Cincinnati          Wofford  0.682266
# 507        Cincinnati             Yale  0.826745
# 508           Colgate             Duke  0.104551
# 509           Colgate      F Dickinson  0.678567
# 510           Colgate          Florida  0.321513
# 511           Colgate       Florida St  0.173750
# 512           Colgate     Gardner Webb  0.746291
# 513           Colgate       Georgia St  0.508785
# 514           Colgate          Gonzaga  0.101007
# 515           Colgate          Houston  0.161826
# 516           Colgate             Iona  0.659710
# 517           Colgate             Iowa  0.398611
# 518           Colgate          Iowa St  0.252777
# 519           Colgate           Kansas  0.273644
# 520           Colgate        Kansas St  0.180011
# 521           Colgate         Kentucky  0.167213
# 522           Colgate          Liberty  0.525144
# 523           Colgate       Louisville  0.343160
# 524           Colgate              LSU  0.225457
# 525           Colgate        Marquette  0.275906
# 526           Colgate         Maryland  0.350355
# 527           Colgate         Michigan  0.180368
# 528           Colgate      Michigan St  0.155521
# 529           Colgate        Minnesota  0.438213
# 530           Colgate      Mississippi  0.415705
# 531           Colgate   Mississippi St  0.241137
# 532           Colgate          Montana  0.412996
# 533           Colgate        Murray St  0.309415
# 534           Colgate      N Dakota St  0.764120
# 535           Colgate       N Kentucky  0.461746
# 536           Colgate       NC Central  0.783130
# 537           Colgate           Nevada  0.178773
# 538           Colgate    New Mexico St  0.220425
# 539           Colgate   North Carolina  0.111681
# 540           Colgate     Northeastern  0.334850
# 541           Colgate          Ohio St  0.387529
# 542           Colgate         Oklahoma  0.403400
# 543           Colgate     Old Dominion  0.454716
# 544           Colgate           Oregon  0.220652
# 545           Colgate     Prairie View  0.673979
# 546           Colgate           Purdue  0.169962
# 547           Colgate       Seton Hall  0.290334
# 548           Colgate        St John's  0.435021
# 549           Colgate         St Louis  0.415618
# 550           Colgate     St Mary's CA  0.323069
# 551           Colgate         Syracuse  0.329386
# 552           Colgate           Temple  0.344208
# 553           Colgate        Tennessee  0.189171
# 554           Colgate       Texas Tech  0.142592
# 555           Colgate        UC Irvine  0.307648
# 556           Colgate              UCF  0.359425
# 557           Colgate          Utah St  0.272666
# 558           Colgate  VA Commonwealth  0.210366
# 559           Colgate          Vermont  0.289439
# 560           Colgate        Villanova  0.194470
# 561           Colgate         Virginia  0.097477
# 562           Colgate    Virginia Tech  0.224585
# 563           Colgate       Washington  0.297755
# 564           Colgate        Wisconsin  0.286895
# 565           Colgate          Wofford  0.267410
# 566           Colgate             Yale  0.459029
# 567              Duke      F Dickinson  0.938996
# 568              Duke          Florida  0.826808
# 569              Duke       Florida St  0.650893
# 570              Duke     Gardner Webb  0.943114
# 571              Duke       Georgia St  0.917639
# 572              Duke          Gonzaga  0.462993
# 573              Duke          Houston  0.642365
# 574              Duke             Iona  0.939791
# 575              Duke             Iowa  0.866371
# 576              Duke          Iowa St  0.778481
# 577              Duke           Kansas  0.743836
# 578              Duke        Kansas St  0.695521
# 579              Duke         Kentucky  0.656881
# 580              Duke          Liberty  0.918671
# 581              Duke       Louisville  0.839360
# 582              Duke              LSU  0.752474
# 583              Duke        Marquette  0.802603
# 584              Duke         Maryland  0.843597
# 585              Duke         Michigan  0.650390
# 586              Duke      Michigan St  0.609145
# 587              Duke        Minnesota  0.865440
# 588              Duke      Mississippi  0.866813
# 589              Duke   Mississippi St  0.788920
# 590              Duke          Montana  0.897383
# 591              Duke        Murray St  0.841853
# 592              Duke      N Dakota St  0.951023
# 593              Duke       N Kentucky  0.913189
# 594              Duke       NC Central  0.956218
# 595              Duke           Nevada  0.723473
# 596              Duke    New Mexico St  0.752695
# 597              Duke   North Carolina  0.500498
# 598              Duke     Northeastern  0.837356
# 599              Duke          Ohio St  0.839532
# 600              Duke         Oklahoma  0.849280
# 601              Duke     Old Dominion  0.888769
# 904           Gonzaga           Kansas  0.709122
# 905           Gonzaga        Kansas St  0.654217
# 906           Gonzaga         Kentucky  0.624970
# 907           Gonzaga          Liberty  0.915844
# 908           Gonzaga       Louisville  0.811798
# 909           Gonzaga              LSU  0.704579
# 910           Gonzaga        Marquette  0.762924
# 911           Gonzaga         Maryland  0.816602
# 912           Gonzaga         Michigan  0.629416
# 913           Gonzaga      Michigan St  0.603376
# 914           Gonzaga        Minnesota  0.847142
# 915           Gonzaga      Mississippi  0.850423
# 916           Gonzaga   Mississippi St  0.747662
# 917           Gonzaga          Montana  0.897296
# 918           Gonzaga        Murray St  0.836069
# 919           Gonzaga      N Dakota St  0.946893
# 920           Gonzaga       N Kentucky  0.905263
# 921           Gonzaga       NC Central  0.953165
# 922           Gonzaga           Nevada  0.717389
# 923           Gonzaga    New Mexico St  0.783920
# 924           Gonzaga   North Carolina  0.464286
# 925           Gonzaga     Northeastern  0.848938
# 926           Gonzaga          Ohio St  0.822926
# 927           Gonzaga         Oklahoma  0.821316
# 928           Gonzaga     Old Dominion  0.877232
# 929           Gonzaga           Oregon  0.761808
# 930           Gonzaga     Prairie View  0.932676
# 931           Gonzaga           Purdue  0.649144
# 932           Gonzaga       Seton Hall  0.769016
# 933           Gonzaga        St John's  0.845178
# 934           Gonzaga         St Louis  0.859149
# 935           Gonzaga     St Mary's CA  0.841531
# 936           Gonzaga         Syracuse  0.799514
# 937           Gonzaga           Temple  0.819873
# 938           Gonzaga        Tennessee  0.627047
# 939           Gonzaga       Texas Tech  0.586319
# 940           Gonzaga        UC Irvine  0.839665
# 941           Gonzaga              UCF  0.816851
# 942           Gonzaga          Utah St  0.804677
# 943           Gonzaga  VA Commonwealth  0.780397
# 944           Gonzaga          Vermont  0.844720
# 945           Gonzaga        Villanova  0.603250
# 946           Gonzaga         Virginia  0.424652
# 947           Gonzaga    Virginia Tech  0.715356
# 948           Gonzaga       Washington  0.774904
# 949           Gonzaga        Wisconsin  0.749278
# 950           Gonzaga          Wofford  0.818329
# 951           Gonzaga             Yale  0.903934
# 952           Houston             Iona  0.915398
# 953           Houston             Iowa  0.807519
# 954           Houston          Iowa St  0.668822
# 955           Houston           Kansas  0.647258
# 956           Houston        Kansas St  0.588642
# 957           Houston         Kentucky  0.538959
# 958           Houston          Liberty  0.891652
# 959           Houston       Louisville  0.767808
# 960           Houston              LSU  0.629632
# 961           Houston        Marquette  0.695066
# 962           Houston         Maryland  0.771603
# 963           Houston         Michigan  0.570024
# 964           Houston      Michigan St  0.515655
# 965           Houston        Minnesota  0.814029
# 966           Houston      Mississippi  0.817695
# 967           Houston   Mississippi St  0.683121
# 968           Houston          Montana  0.863035
# 969           Houston        Murray St  0.790080
# 970           Houston      N Dakota St  0.929625
# 971           Houston       N Kentucky  0.874253
# 972           Houston       NC Central  0.933768
# 973           Houston           Nevada  0.630668
# 974           Houston    New Mexico St  0.689174
# 975           Houston   North Carolina  0.422945
# 976           Houston     Northeastern  0.803210
# 977           Houston          Ohio St  0.786832
# ...
# 1952     Northeastern             Yale  0.634368
